# %% [markdown]
# ## DMRG WITH TENPY

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import pickle
import os


import tenpy
from tenpy import CouplingMPOModel, SpinHalfSite
import tenpy.linalg.np_conserved as npc
from tenpy.algorithms import dmrg
from tenpy.networks.mps import MPS
from tenpy.models.tf_ising import TFIChain

np.set_printoptions(precision=5, suppress=True, linewidth=100)
plt.rcParams['figure.dpi'] = 150
tenpy.tools.misc.setup_logging(to_stdout="INFO")

# %%
L = 40


filename = os.path.join(os.getcwd(), "TFIM")

# %% [markdown]
# ## My MPO

# %%
class myModel(CouplingMPOModel):
    def init_sites(self, model_params):
        return SpinHalfSite(conserve='None')
    
    def init_terms(self, model_params):
        Jx = model_params.get('Jx', 1.0)
        hz = model_params.get('hz', 0.0)
        kl = model_params.get('kl', 0.0)
        kr = model_params.get('kr', 0.0)

        # Onsite magnetic field
        for u in range(len(self.lat.unit_cell)):
            self.add_onsite(hz, u, 'Sz')

        # Nearest-neighbor XX coupling
        for u1, u2, dx in self.lat.pairs['nearest_neighbors']:
            self.add_coupling(Jx, u1, 'Sx', u2, 'Sx', dx)

        # 3-site interactions (already Hermitian)
        dx = [(0,), (1,), (2,)]
        u = 0  # single-site unit cell

        self.add_multi_coupling(
            -kl,
            [('Sx', dx[0], u), ('Sy', dx[1], u), ('Sz', dx[2], u)]
        )
        self.add_multi_coupling(
            kl,
            [('Sy', dx[0], u), ('Id', dx[1], u), ('Sx', dx[2], u)]
        )
        self.add_multi_coupling(
            -kr,
            [('Sz', dx[0], u), ('Sy', dx[1], u), ('Sx', dx[2], u)]
        )
        self.add_multi_coupling(
            kr,
            [('Sx', dx[0], u), ('Id', dx[1], u), ('Sy', dx[2], u)]
        )

        # add boundary conditions
        self.add_onsite_term(20, 0, "Sx")
        self.add_onsite_term(-20, L-1, "Sx")

def dmrg_sim(Jx, hz, kl, kr, filename=filename):
    dmrg_params = {
    'mixer': None,  # setting this to True helps to escape local minima
    'max_E_err': 1.e-10,
    'trunc_params': {
        'chi_max': 200,
        'svd_min': 1.e-10,
    },
    'verbose': True,
    'combine': True
    }

    model_params = {
    'Jx': Jx , 'hz': hz, 'kl': kl, 'kr': kr,
    'L': L,
    'bc_MPS': 'finite',
    }

    M = myModel(model_params)
    psi = MPS.from_lat_product_state(M.lat, [['up']])

    eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
    E, psi = eng.run() # the main work; modifies psi in place

    # save to file
    data = {'psi': psi, 'dmrg_params': dmrg_params, 'model_params': model_params}

    if not os.path.exists(filename):
        os.mkdir(filename)
        
    loc = os.path.join(filename, f'{hz:.3f}_{kl:.3f}.pkl')
    with open(loc, 'wb') as f:
        pickle.dump(data, f)

def dmrg_lines(start, stop, step, fixed, setval="k", Jx=1):
    values = np.arange(start, stop+step, step)

    for sweep in values:
        if setval == "k":
            hz = sweep
            k = fixed
        elif setval == "h":
            hz = fixed
            k = sweep
        
        dmrg_sim(Jx, hz, k, k)

dmrg_lines(1, 0, -0.1, 0.5, setval="h")
# Out:
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(1.0)
# INFO    : myModel: reading 'kr'=np.float64(1.0)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-37.4909874860908516, max S=0.2297722048685216, age=40, norm_err=2.9e-01
# Current memory usage 164.6MB, wall time: 0.3s
# Delta E = nan, Delta S = 1.1883e-01 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-37.5347021995870236, max S=0.3172374887683937, age=40, norm_err=5.8e-03
# Current memory usage 175.2MB, wall time: 1.0s
# Delta E = -4.3715e-02, Delta S = 1.3465e-01 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 8.5265e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-37.5347626280655646, max S=0.3174740835115940, age=40, norm_err=2.5e-06
# Current memory usage 196.7MB, wall time: 4.9s
# Delta E = -6.0428e-05, Delta S = 5.3192e-03 (per sweep)
# max trunc_err = 2.0233e-20, max E_trunc = 1.7764e-13
# chi: 64
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-37.5347626304144129, max S=0.3174741381179584, age=40, norm_err=2.6e-10
# Current memory usage 423.6MB, wall time: 166.6s
# Delta E = -2.3488e-09, Delta S = 6.3589e-06 (per sweep)
# max trunc_err = 4.5518e-17, max E_trunc = 1.4211e-13
# chi: 200
# ================================================================================
# INFO    : Running sweep with optimization
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 91
#      87             k = sweep
#      89         dmrg_sim(Jx, hz, k, k)
# ---> 91 dmrg_lines(1, 0, -0.1, 0.5, setval="h")
#
# Cell In[4], line 89, in dmrg_lines(start, stop, step, fixed, setval, Jx)
#      86     hz = fixed
#      87     k = sweep
# ---> 89 dmrg_sim(Jx, hz, k, k)
#
# Cell In[4], line 66, in dmrg_sim(Jx, hz, kl, kr, filename)
#      63 psi = MPS.from_lat_product_state(M.lat, [['up']])
#      65 eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
# ---> 66 E, psi = eng.run() # the main work; modifies psi in place
#      68 # save to file
#      69 data = {'psi': psi, 'dmrg_params': dmrg_params, 'model_params': model_params}
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/algorithms/dmrg.py:453, in DMRGEngine.run(self)
#     441 def run(self):
#     442     """Run the DMRG simulation to find the ground state.
#     443
#     444     Returns
#    (...)
#     451
#     452     """
# --> 453     return super().run()
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/algorithms/mps_common.py:806, in IterativeSweeps.run(self)
#     804 if not is_first_sweep:
#     805     self.checkpoint.emit(self)
# --> 806 result = self.run_iteration()
#     807 self.status_update(iteration_start_time=iteration_start_time)
#     808 is_first_sweep = False
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/algorithms/dmrg.py:298, in DMRGEngine.run_iteration(self)
#     296 for i in range(self.N_sweeps_check - 1):
#     297     self.sweep(meas_E_trunc=False)
# --> 298 max_trunc_err = self.sweep(meas_E_trunc=True)
#     299 max_E_trunc = np.max(self.E_trunc_list)
#     301 # update lanczos_params depending on truncation error(s)
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/algorithms/dmrg.py:527, in DMRGEngine.sweep(self, optimize, meas_E_trunc)
#     521 """One 'sweep' of the algorithm.
#     522
#     523 Thin wrapper around :meth:`tenpy.algorithms.mps_common.Sweep.sweep` with one additional
#     524 parameter `meas_E_trunc` specifying whether to measure truncation energies.
#     525 """
#     526 self._meas_E_trunc = meas_E_trunc
# --> 527 return super().sweep(optimize)
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/algorithms/mps_common.py:402, in Sweep.sweep(self, optimize)
#     400 # --------- the main work --------------
#     401 theta = self.prepare_update_local()
# --> 402 update_data = self.update_local(theta, optimize=optimize)
#     403 self.update_env(**update_data)
#     404 self.post_update_local(**update_data)
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/algorithms/dmrg.py:565, in DMRGEngine.update_local(self, theta, optimize)
#     563 age = self.env.get_LP_age(i0) + n_opt + self.env.get_RP_age(i0 + n_opt - 1)
#     564 if optimize:
# --> 565     E0, theta, N, ov_change = self.diag(theta)
#     566 else:
#     567     E0, N, ov_change = None, 0, 0.0
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/algorithms/dmrg.py:740, in DMRGEngine.diag(self, theta_guess)
#     738         E, theta = full_diag_effH(self.eff_H, theta_guess, keep_sector=True)
#     739     else:
# --> 740         E, theta, N = LanczosGroundState(self.eff_H, theta_guess, self.lanczos_params).run()
#     741 elif self.diag_method == 'lanczos':
#     742     E, theta, N = LanczosGroundState(self.eff_H, theta_guess, self.lanczos_params).run()
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/linalg/krylov_based.py:500, in LanczosGroundState.run(self)
#     487 def run(self):
#     488     """Find the ground state of H.
#     489
#     490     Returns
#    (...)
#     498
#     499     """
# --> 500     N = self._build_krylov()
#     501     E0 = self.Es[N - 1, 0]
#     502     if N > 1:
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/linalg/krylov_based.py:544, in LanczosGroundState._build_krylov(self)
#     542 elif k > 0:
#     543     self.iadd_prefactor_other(w, -beta, self._cache[-2])
# --> 544 beta = npc.norm(w)
#     545 h[k, k + 1] = h[k + 1, k] = beta  # needed for the next step and convergence criteria
#     546 if abs(beta) < self._cutoff or (k + 1 >= self.N_min and self._converged(k)):
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/linalg/np_conserved.py:3887, in norm(a, ord, convert_to_float)
#    3853 r"""Norm of flattened data.
#    3854
#    3855 Equivalent to ``np.linalg.norm(a.to_ndarray().flatten(), ord)``.
#    (...)
#    3884
#    3885 """
#    3886 if isinstance(a, Array):
# -> 3887     return a.norm(ord, convert_to_float)
#    3888 elif isinstance(a, np.ndarray):
#    3889     if convert_to_float:
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/linalg/np_conserved.py:2252, in Array.norm(self, ord, convert_to_float)
#    2250     if new_type != self.dtype:
#    2251         return self.astype(new_type).norm(ord, False)
# -> 2252 block_norms = [np.linalg.norm(t.reshape(-1), ord) for t in self._data]
#    2253 # ``.reshape(-1) gives a 1D view and is thus faster than ``.flatten()``
#    2254 # add a [0] in the list to ensure correct results for ``ord=-inf``
#    2255 return np.linalg.norm(block_norms + [0], ord)
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/linalg/np_conserved.py:2252, in <listcomp>(.0)
#    2250     if new_type != self.dtype:
#    2251         return self.astype(new_type).norm(ord, False)
# -> 2252 block_norms = [np.linalg.norm(t.reshape(-1), ord) for t in self._data]
#    2253 # ``.reshape(-1) gives a 1D view and is thus faster than ``.flatten()``
#    2254 # add a [0] in the list to ensure correct results for ``ord=-inf``
#    2255 return np.linalg.norm(block_norms + [0], ord)
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/numpy/linalg/_linalg.py:2742, in norm(x, ord, axis, keepdims)
#    2740     x_real = x.real
#    2741     x_imag = x.imag
# -> 2742     sqnorm = x_real.dot(x_real) + x_imag.dot(x_imag)
#    2743 else:
#    2744     sqnorm = x.dot(x)
#
# KeyboardInterrupt:

# %%
print(M.all_coupling_terms().to_TermList() + M.all_onsite_terms().to_TermList())
# Out:
# 1.00000 * Sx_0 Sx_1 +
# 1.00000 * Sx_1 Sx_2 +
# 1.00000 * Sx_2 Sx_3 +
# 1.00000 * Sx_3 Sx_4 +
# 1.00000 * Sx_4 Sx_5 +
# 1.00000 * Sx_5 Sx_6 +
# 1.00000 * Sx_6 Sx_7 +
# 1.00000 * Sx_7 Sx_8 +
# 1.00000 * Sx_8 Sx_9 +
# 1.00000 * Sx_9 Sx_10 +
# 1.00000 * Sx_10 Sx_11 +
# 1.00000 * Sx_11 Sx_12 +
# 1.00000 * Sx_12 Sx_13 +
# 1.00000 * Sx_13 Sx_14 +
# 1.00000 * Sx_14 Sx_15 +
# 1.00000 * Sx_15 Sx_16 +
# 1.00000 * Sx_16 Sx_17 +
# 1.00000 * Sx_17 Sx_18 +
# 1.00000 * Sx_18 Sx_19 +
# 1.00000 * Sx_19 Sx_20 +
# 1.00000 * Sx_20 Sx_21 +
# 1.00000 * Sx_21 Sx_22 +
# 1.00000 * Sx_22 Sx_23 +
# 1.00000 * Sx_23 Sx_24 +
# 1.00000 * Sx_24 Sx_25 +
# 1.00000 * Sx_25 Sx_26 +
# 1.00000 * Sx_26 Sx_27 +
# 1.00000 * Sx_27 Sx_28 +
# 1.00000 * Sx_28 Sx_29 +
# 1.00000 * Sx_29 Sx_30 +
# 1.00000 * Sx_30 Sx_31 +
# 1.00000 * Sx_31 Sx_32 +
# 1.00000 * Sx_32 Sx_33 +
# 1.00000 * Sx_33 Sx_34 +
# 1.00000 * Sx_34 Sx_35 +
# 1.00000 * Sx_35 Sx_36 +
# 1.00000 * Sx_36 Sx_37 +
# 1.00000 * Sx_37 Sx_38 +
# 1.00000 * Sx_38 Sx_39 +
# 1.00000 * Sx_39 Sx_40 +
# 1.00000 * Sx_40 Sx_41 +
# 1.00000 * Sx_41 Sx_42 +
# 1.00000 * Sx_42 Sx_43 +
# 1.00000 * Sx_43 Sx_44 +
# 1.00000 * Sx_44 Sx_45 +
# 1.00000 * Sz_87 +
# 1.00000 * Sz_88 +
# 1.00000 * Sz_89 +
# 1.00000 * Sz_90 +
# 1.00000 * Sz_91 +
# 1.00000 * Sz_92 +
# 1.00000 * Sz_93 +
# 1.00000 * Sz_94 +
# 1.00000 * Sz_95 +
# 1.00000 * Sz_96 +
# 1.00000 * Sz_97 +
# 1.00000 * Sz_98 +
# 1.00000 * Sz_99 +
# 1.00000 * Sz_100 +
# 1.00000 * Sz_101 +
# 1.00000 * Sz_102 +
# 1.00000 * Sz_103 +
# 1.00000 * Sz_104 +
# 1.00000 * Sz_105 +
# 1.00000 * Sz_106 +
# 1.00000 * Sz_107 +
# 1.00000 * Sz_108 +
# 1.00000 * Sz_109 +
# 1.00000 * Sz_110 +
# 1.00000 * Sz_111 +
# 1.00000 * Sz_112 +
# 1.00000 * Sz_113 +
# 1.00000 * Sz_114 +
# 1.00000 * Sz_115 +
# 1.00000 * Sz_116 +
# 1.00000 * Sz_117 +
# 1.00000 * Sz_118 +
# -20.00000 * Sx_119 +
# 1.00000 * Sz_119

# %% [markdown]
# ## Energy

# %% [markdown]
# ## Magnetization Profile

# %%
# onsite expectation values
filename = os.path.join(os.getcwd(), "First_Run")
print(filename)

for i in os.listdir(filename):

    plt.figure(figsize=(15, 5))
    loc = os.path.join(filename, i)
    with open(loc, 'rb') as f:
        data = pickle.load(f)
        psi = data['psi']
    
    i = os.path.splitext(i)[0]
    h, k = i.split("_")

    x = np.arange(psi.L)
    X = psi.expectation_value("Sigmax")
    Z = psi.expectation_value("Sigmaz")
    Y = psi.expectation_value("Sigmay")
    
    plt.plot(x, X, label=f"X, {h}, {k}")
    plt.plot(x, Y, label=f"Y, {h}, {k}")
    plt.plot(x, Z, label=f"Z, {h}, {k}")
   
    plt.xlabel("site")
    plt.ylabel("onsite expectation value")
    plt.legend()
    plt.show()
# Out:
# /home/ioannisangelotassioulas/Documents/master_thesis/books/First_Run

# %% [markdown]
# ## Correlation Functions

# %%
# correlation functions

print(filename)

for i in os.listdir(filename):

    loc = os.path.join(filename, i)
    with open(loc, 'rb') as f:
        data = pickle.load(f)
        psi = data['psi']
    
    i = os.path.splitext(i)[0]
    h, k = i.split("_")

    i0 = psi.L // 2  # for fixed `i`
    j = np.arange(i0 + 1, psi.L)

    XX = psi.term_correlation_function_right([("Sigmax", 0)], [("Sigmax", 0)], i_L=i0, j_R=j)
    XX_disc = XX - X[i0] * X[j]

    YY = psi.term_correlation_function_right([("Sigmay", 0)], [("Sigmay", 0)], i_L=i0, j_R=j)
    YY_disc = YY - Y[i0] * Y[j]

    ZZ = psi.term_correlation_function_right([("Sigmaz", 0)], [("Sigmaz", 0)], i_L=i0, j_R=j)
    ZZ_disc = ZZ - Z[i0] * Z[j]

    XY = psi.term_correlation_function_right([("Sigmax", 0)], [("Sigmay", 0)], i_L=i0, j_R=j)
    XY_disc = XY - X[i0] * Y[j]

    XZ = psi.term_correlation_function_right([("Sigmax", 0)], [("Sigmaz", 0)], i_L=i0, j_R=j)
    XZ_disc = XZ - X[i0] * Z[j]

    YZ = psi.term_correlation_function_right([("Sigmay", 0)], [("Sigmaz", 0)], i_L=i0, j_R=j)
    YZ_disc = YZ - Y[i0] * Z[j]


    dx = j - i0
    plt.figure()
    plt.plot(dx, XX_disc, label="X X")
    # plt.plot(dx, YY_disc, label="Y Y")
    plt.plot(dx, ZZ_disc, label="Z Z")
    # plt.plot(dx, XY_disc, label="X Y")
    plt.plot(dx, XZ_disc, label="X Z")
    plt.plot(dx, YZ_disc, label="Y Z")
    plt.xlabel(r"distance $|i-j|$")
    plt.ylabel(r"disconnected correlations $\langle A_i A_j\rangle - \langle A_i \rangle\langle A_j\rangle$")
    plt.title(f"Correlations ({h}, {k})")
    plt.legend()
    plt.semilogy()
    plt.show()
# Out:
# /home/ioannisangelotassioulas/Documents/master_thesis/books/First_Run
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 33
#      30 XZ = psi.term_correlation_function_right([("Sigmax", 0)], [("Sigmaz", 0)], i_L=i0, j_R=j)
#      31 XZ_disc = XZ - X[i0] * Z[j]
# ---> 33 YZ = psi.term_correlation_function_right([("Sigmay", 0)], [("Sigmaz", 0)], i_L=i0, j_R=j)
#      34 YZ_disc = YZ - Y[i0] * Z[j]
#      37 dx = j - i0
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/networks/mps.py:1043, in BaseMPSExpectationValue.term_correlation_function_right(self, term_L, term_R, i_L, j_R, autoJW, opstr)
#    1041 # contract CL with tensors on site `k`
#    1042 B_ket = ket.get_B(k, form='B')
# -> 1043 CL = npc.tensordot(CL, B_ket, axes=['vR', 'vL'])
#    1044 if opstr is not None:
#    1045     opstr_k = self.get_site(k).get_op(opstr)
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/linalg/np_conserved.py:3659, in tensordot(a, b, axes)
#    3654 if one_block:
#    3655     # optimize for special case that a and b have only 1 entry
#    3656     # this is (usually) the case if we have trivial charges
#    3657     if np.all(a._qdata[0, cut_a:] == b._qdata[0, :axes]):  # blocks fit together
#    3658         # contract inner axes
# -> 3659         res._data = [np.tensordot(a._data[0], b._data[0], axes=axes)]
#    3660         c_qdata = np.empty([1, res.rank], np.intp)
#    3661         c_qdata[0, :cut_a] = a._qdata[0, :cut_a]
#
# File ~/Documents/master_thesis/.venv/lib64/python3.10/site-packages/numpy/_core/numeric.py:1177, in tensordot(a, b, axes)
#    1175 at = a.transpose(newaxes_a).reshape(newshape_a)
#    1176 bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1177 res = dot(at, bt)
#    1178 return res.reshape(olda + oldb)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Entanglement Entropy

# %%
S = psi.entanglement_entropy()

bonds = np.arange(0.5, psi.L-1)
plt.plot(bonds, S, 'o', label="S")

# preform fit to extract the central charge
central_charge, const, res = tenpy.tools.fit.central_charge_from_S_profile(psi)
fit = tenpy.tools.fit.entropy_profile_from_CFT(bonds + 0.5, psi.L, central_charge, const)
print(f"extraced central charge {central_charge:.5f} with residuum {res:.2e}")
print("(Expect central charge = 0.5 for the transverse field Ising model.)")
plt.plot(bonds, fit, label=f"fit with $c={central_charge:.3f}$")
plt.xlabel("bond")
plt.ylabel("entanglement entropy $S$")
plt.legend()
plt.show()
# Out:
# extraced central charge 0.47896 with residuum 4.26e-09
# (Expect central charge = 0.5 for the transverse field Ising model.)
