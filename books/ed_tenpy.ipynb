# %% [markdown]
# ## EXACT DIAGONALIZATION WITH TENPY

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
np.set_printoptions(precision=5, suppress=True, linewidth=100)
plt.rcParams['figure.dpi'] = 150

import tenpy
from tenpy import CouplingMPOModel, SpinHalfSite
import tenpy.linalg.np_conserved as npc
from tenpy.algorithms import dmrg
from tenpy.networks.mps import MPS
from tenpy.models.tf_ising import TFIChain

tenpy.tools.misc.setup_logging(to_stdout="INFO")

# %%
L = 120

# %% [markdown]
# ## My MPO

# %%
class myModel(CouplingMPOModel):
    def init_sites(self, model_params):
        return SpinHalfSite(conserve='None')
    
    def init_terms(self, model_params):
        Jx = model_params.get('Jx', 1.0)
        hz = model_params.get('hz', 0.0)
        kl = model_params.get('kl', 0.0)
        kr = model_params.get('kr', 0.0)

        # Onsite magnetic field
        for u in range(len(self.lat.unit_cell)):
            self.add_onsite(hz, u, 'Sz')

        # Nearest-neighbor XX coupling
        for u1, u2, dx in self.lat.pairs['nearest_neighbors']:
            self.add_coupling(Jx, u1, 'Sx', u2, 'Sx', dx)

        # 3-site interactions (already Hermitian)
        dx = [(0,), (1,), (2,)]
        u = 0  # single-site unit cell

        self.add_multi_coupling(
            -kl,
            [('Sx', dx[0], u), ('Sy', dx[1], u), ('Sz', dx[2], u)]
        )
        self.add_multi_coupling(
            kl,
            [('Sy', dx[0], u), ('Id', dx[1], u), ('Sx', dx[2], u)]
        )
        self.add_multi_coupling(
            -kr,
            [('Sz', dx[0], u), ('Sy', dx[1], u), ('Sx', dx[2], u)]
        )
        self.add_multi_coupling(
            kr,
            [('Sx', dx[0], u), ('Id', dx[1], u), ('Sy', dx[2], u)]
        )

# %%
model_params = {
    'Jx': 1. , 'hz': 1., 'kl': 0, 'kr': 0,
    'L': L,
    'bc_MPS': 'finite',
}

M = myModel(model_params)
# Out:
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=120
# INFO    : myModel: reading 'Jx'=1.0
# INFO    : myModel: reading 'hz'=1.0
# INFO    : myModel: reading 'kl'=0
# INFO    : myModel: reading 'kr'=0

# %%
psi = MPS.from_lat_product_state(M.lat, [['up']])

# %%
print(M.all_coupling_terms().to_TermList() + M.all_onsite_terms().to_TermList())
# Out:
# 1.00000 * Sx_0 Sx_1 +
# 1.00000 * Sx_1 Sx_2 +
# 1.00000 * Sx_2 Sx_3 +
# 1.00000 * Sx_3 Sx_4 +
# 1.00000 * Sx_4 Sx_5 +
# 1.00000 * Sx_5 Sx_6 +
# 1.00000 * Sx_6 Sx_7 +
# 1.00000 * Sx_7 Sx_8 +
# 1.00000 * Sx_8 Sx_9 +
# 1.00000 * Sx_9 Sx_10 +
# 1.00000 * Sx_10 Sx_11 +
# 1.00000 * Sx_11 Sx_12 +
# 1.00000 * Sx_12 Sx_13 +
# 1.00000 * Sx_13 Sx_14 +
# 1.00000 * Sx_14 Sx_15 +
# 1.00000 * Sx_15 Sx_16 +
# 1.00000 * Sx_16 Sx_17 +
# 1.00000 * Sx_17 Sx_18 +
# 1.00000 * Sx_18 Sx_19 +
# 1.00000 * Sz_50 +
# 1.00000 * Sz_51 +
# 1.00000 * Sz_52 +
# 1.00000 * Sz_53 +
# 1.00000 * Sz_54 +
# 1.00000 * Sz_55 +
# 1.00000 * Sz_56 +
# 1.00000 * Sz_57 +
# 1.00000 * Sz_58 +
# 1.00000 * Sz_59 +
# 1.00000 * Sz_60 +
# 1.00000 * Sz_61 +
# 1.00000 * Sz_62 +
# 1.00000 * Sz_63 +
# 1.00000 * Sz_64 +
# 1.00000 * Sz_65 +
# 1.00000 * Sz_66 +
# 1.00000 * Sz_67 +
# 1.00000 * Sz_68 +
# 1.00000 * Sz_69 +
# 1.00000 * Sz_70 +
# 1.00000 * Sz_71 +
# 1.00000 * Sz_72 +
# 1.00000 * Sz_73 +
# 1.00000 * Sz_74 +
# 1.00000 * Sz_75 +
# 1.00000 * Sz_76 +
# 1.00000 * Sz_77 +
# 1.00000 * Sz_78 +
# 1.00000 * Sz_79 +
# 1.00000 * Sz_80 +
# 1.00000 * Sz_81 +
# 1.00000 * Sz_82 +
# 1.00000 * Sz_83 +
# 1.00000 * Sz_84 +
# 1.00000 * Sz_85 +
# 1.00000 * Sz_86 +
# 1.00000 * Sz_87 +
# 1.00000 * Sz_88 +
# 1.00000 * Sz_89 +
# 1.00000 * Sz_90 +
# 1.00000 * Sz_91 +
# 1.00000 * Sz_92 +
# 1.00000 * Sz_93 +
# 1.00000 * Sz_94 +
# 1.00000 * Sz_95 +
# 1.00000 * Sz_96 +
# 1.00000 * Sz_97 +
# 1.00000 * Sz_98 +
# 1.00000 * Sz_99 +
# 1.00000 * Sz_100 +
# 1.00000 * Sz_101 +
# 1.00000 * Sz_102 +
# 1.00000 * Sz_103 +
# 1.00000 * Sz_104 +
# 1.00000 * Sz_105 +
# 1.00000 * Sz_106 +
# 1.00000 * Sz_107 +
# 1.00000 * Sz_108 +
# 1.00000 * Sz_109 +
# 1.00000 * Sz_110 +
# 1.00000 * Sz_111 +
# 1.00000 * Sz_112 +
# 1.00000 * Sz_113 +
# 1.00000 * Sz_114 +
# 1.00000 * Sz_115 +
# 1.00000 * Sz_116 +
# 1.00000 * Sz_117 +
# 1.00000 * Sz_118 +
# 1.00000 * Sz_119

# %% [markdown]
# ## DMRG

# %%
dmrg_params = {
    'mixer': None,  # setting this to True helps to escape local minima
    'max_E_err': 1.e-10,
    'trunc_params': {
        'chi_max': 200,
        'svd_min': 1.e-10,
    },
    'verbose': True,
    'combine': True
}
eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
E, psi = eng.run() # the main work; modifies psi in place
# Out:
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))
#
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-63.7797718811807641, max S=0.0886831339714451, age=120, norm_err=1.8e-03
# Current memory usage 265.7MB, wall time: 1.0s
# Delta E = nan, Delta S = 8.8524e-02 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.4921e-13
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 2
# energy=-63.7797723272359605, max S=0.0888429730663008, age=120, norm_err=2.0e-08
# Current memory usage 265.7MB, wall time: 2.9s
# Delta E = -4.4606e-07, Delta S = 1.9858e-04 (per sweep)
# max trunc_err = 9.2321e-21, max E_trunc = 1.9185e-13
# chi: 12
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-63.7797723272357047, max S=0.0888429735324495, age=120, norm_err=1.3e-13
# Current memory usage 265.7MB, wall time: 1.4s
# Delta E = 2.5580e-13, Delta S = 9.1316e-10 (per sweep)
# max trunc_err = 1.1607e-20, max E_trunc = 1.3500e-13
# chi: 15
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 3 sweeps, max chi=15

# %% [markdown]
# ## Energy

# %%
# the ground state energy was directly returned by dmrg.run()
print("ground state energy = ", E)

# there are other ways to extract the energy from psi:
E1 = M.H_MPO.expectation_value(psi)  # based on the MPO
# E2 = np.sum(M.bond_energies(psi))  # based on bond terms of H, works only for a NearestNeighborModel
# assert abs(E-E1) < 1.e-10 and abs(E-E2) < 1.e-10
# Out:
# ground state energy =  -12.802323957225639

# %% [markdown]
# ## Magnetization Profile

# %%
# onsite expectation values

X = psi.expectation_value("Sigmax")
Z = psi.expectation_value("Sigmaz")
Y = psi.expectation_value("Sigmay")
x = np.arange(psi.L)
plt.figure()
plt.plot(x, Z, label="Z")
plt.plot(x, X, label="X")
plt.plot(x, Y, label="Y")
plt.xlabel("site")
plt.ylabel("onsite expectation value")
plt.legend()
plt.show()

# %% [markdown]
# ## Correlation Functions

# %%
# correlation functions

i0 = psi.L // 2  # for fixed `i`
j = np.arange(i0 + 1, psi.L)

XX = psi.term_correlation_function_right([("Sigmax", 0)], [("Sigmax", 0)], i_L=i0, j_R=j)
XX_disc = XX - X[i0] * X[j]

YY = psi.term_correlation_function_right([("Sigmay", 0)], [("Sigmay", 0)], i_L=i0, j_R=j)
YY_disc = YY - Y[i0] * Y[j]

ZZ = psi.term_correlation_function_right([("Sigmaz", 0)], [("Sigmaz", 0)], i_L=i0, j_R=j)
ZZ_disc = ZZ - Z[i0] * Z[j]

dx = j - i0
plt.figure()
plt.plot(dx, np.abs(XX_disc), label="X X")
plt.plot(dx, np.abs(YY_disc), label="Y Y")
plt.plot(dx, np.abs(ZZ_disc), label="Z Z")
plt.xlabel(r"distance $|i-j|$")
plt.ylabel(r"disconnected correlations $\langle A_i A_j\rangle - \langle A_i \rangle\langle A_j\rangle$")
plt.legend()
plt.semilogy()
plt.show()

# %% [markdown]
# ## Entanglement Entropy

# %%
S = psi.entanglement_entropy()

bonds = np.arange(0.5, psi.L-1)
plt.plot(bonds, S, 'o', label="S")

# preform fit to extract the central charge
central_charge, const, res = tenpy.tools.fit.central_charge_from_S_profile(psi)
fit = tenpy.tools.fit.entropy_profile_from_CFT(bonds + 0.5, psi.L, central_charge, const)
print(f"extraced central charge {central_charge:.5f} with residuum {res:.2e}")
print("(Expect central charge = 0.5 for the transverse field Ising model.)")
plt.plot(bonds, fit, label=f"fit with $c={central_charge:.3f}$")
plt.xlabel("bond")
plt.ylabel("entanglement entropy $S$")
plt.legend()
plt.show()
# Out:
# extraced central charge -0.00000 with residuum 3.93e-29
# (Expect central charge = 0.5 for the transverse field Ising model.)
