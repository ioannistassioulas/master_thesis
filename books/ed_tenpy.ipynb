# %% [markdown]
# ## DMRG WITH TENPY

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import pickle
import os


import tenpy
from tenpy import CouplingMPOModel, SpinHalfSite
import tenpy.linalg.np_conserved as npc
from tenpy.algorithms import dmrg
from tenpy.networks.mps import MPS
from tenpy.models.tf_ising import TFIChain

np.set_printoptions(precision=5, suppress=True, linewidth=100)
plt.rcParams['figure.dpi'] = 150
tenpy.tools.misc.setup_logging(to_stdout="INFO")

# %%
L = 40


filename = os.path.join(os.getcwd(), "h=0.5, 1>k>0")

# %% [markdown]
# ## My MPO

# %%
class myModel(CouplingMPOModel):
    def init_sites(self, model_params):
        return SpinHalfSite(conserve='None')
    
    def init_terms(self, model_params):
        Jx = model_params.get('Jx', 1.0)
        hz = model_params.get('hz', 0.0)
        kl = model_params.get('kl', 0.0)
        kr = model_params.get('kr', 0.0)

        # Onsite magnetic field
        for u in range(len(self.lat.unit_cell)):
            self.add_onsite(hz, u, 'Sz')

        # Nearest-neighbor XX coupling
        for u1, u2, dx in self.lat.pairs['nearest_neighbors']:
            self.add_coupling(Jx, u1, 'Sx', u2, 'Sx', dx)

        # 3-site interactions (already Hermitian)
        dx = [(0,), (1,), (2,)]
        u = 0  # single-site unit cell

        self.add_multi_coupling(
            -kl,
            [('Sx', dx[0], u), ('Sy', dx[1], u), ('Sz', dx[2], u)]
        )
        self.add_multi_coupling(
            kl,
            [('Sy', dx[0], u), ('Id', dx[1], u), ('Sx', dx[2], u)]
        )
        self.add_multi_coupling(
            -kr,
            [('Sz', dx[0], u), ('Sy', dx[1], u), ('Sx', dx[2], u)]
        )
        self.add_multi_coupling(
            kr,
            [('Sx', dx[0], u), ('Id', dx[1], u), ('Sy', dx[2], u)]
        )

        # add boundary conditions
        self.add_onsite_term(20, 0, "Sx")
        self.add_onsite_term(-20, L-1, "Sx")

def dmrg_sim(Jx, hz, kl, kr, filename=filename):
    dmrg_params = {
    'mixer': None,  # setting this to True helps to escape local minima
    'max_E_err': 1.e-10,
    'trunc_params': {
        'chi_max': 200,
        'svd_min': 1.e-10,
    },
    'verbose': True,
    'combine': True
    }

    model_params = {
    'Jx': Jx , 'hz': hz, 'kl': kl, 'kr': kr,
    'L': L,
    'bc_MPS': 'finite',
    }

    M = myModel(model_params)
    psi = MPS.from_lat_product_state(M.lat, [['up']])

    eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
    E, psi = eng.run() # the main work; modifies psi in place

    # save to file
    data = {'psi': psi, 'dmrg_params': dmrg_params, 'model_params': model_params}

    if not os.path.exists(filename):
        os.mkdir(filename)
        
    loc = os.path.join(filename, f'{hz:.3f}_{kl:.3f}.pkl')
    with open(loc, 'wb') as f:
        pickle.dump(data, f)

def dmrg_lines(start, stop, step, fixed, setval="k", Jx=1):
    values = np.arange(start, stop+step, step)

    for sweep in values:
        if setval == "k":
            hz = sweep
            k = fixed
        elif setval == "h":
            hz = fixed
            k = sweep
        
        dmrg_sim(Jx, hz, k, k)

dmrg_lines(1, 0, -0.1, 0.5, setval="h")
# Out:
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(1.0)
# INFO    : myModel: reading 'kr'=np.float64(1.0)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-37.4909874860908516, max S=0.2297722048685216, age=40, norm_err=2.9e-01
# Current memory usage 562.6MB, wall time: 0.3s
# Delta E = nan, Delta S = 1.1883e-01 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-37.5347021995870236, max S=0.3172374887683937, age=40, norm_err=5.8e-03
# Current memory usage 562.8MB, wall time: 1.3s
# Delta E = -4.3715e-02, Delta S = 1.3465e-01 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 8.5265e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-37.5347626280655646, max S=0.3174740835115940, age=40, norm_err=2.5e-06
# Current memory usage 562.8MB, wall time: 6.8s
# Delta E = -6.0428e-05, Delta S = 5.3192e-03 (per sweep)
# max trunc_err = 2.0233e-20, max E_trunc = 1.7764e-13
# chi: 64
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-37.5347626304144129, max S=0.3174741381179584, age=40, norm_err=2.6e-10
# Current memory usage 761.4MB, wall time: 153.3s
# Delta E = -2.3488e-09, Delta S = 6.3589e-06 (per sweep)
# max trunc_err = 4.5518e-17, max E_trunc = 1.4211e-13
# chi: 200
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-37.5347626304144910, max S=0.3174741381187928, age=40, norm_err=8.9e-13
# Current memory usage 787.8MB, wall time: 55.1s
# Delta E = -7.8160e-14, Delta S = 2.9587e-10 (per sweep)
# max trunc_err = 1.1606e-16, max E_trunc = 2.4158e-13
# chi: 200
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 5 sweeps, max chi=200
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))
#
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(0.9)
# INFO    : myModel: reading 'kr'=np.float64(0.9)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-36.5345468479710718, max S=0.2066781422242326, age=40, norm_err=2.5e-01
# Current memory usage 787.8MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.0603e-01 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 4.9738e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-36.5605390838825244, max S=0.2823770719727277, age=40, norm_err=4.0e-03
# Current memory usage 787.8MB, wall time: 1.2s
# Delta E = -2.5992e-02, Delta S = 1.2102e-01 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 6.3949e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-36.5605734397174800, max S=0.2825475885426726, age=40, norm_err=1.7e-06
# Current memory usage 787.8MB, wall time: 6.3s
# Delta E = -3.4356e-05, Delta S = 3.7015e-03 (per sweep)
# max trunc_err = 2.6653e-20, max E_trunc = 1.2079e-13
# chi: 64
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-36.5605734408405425, max S=0.2825476260549085, age=40, norm_err=1.3e-10
# Current memory usage 787.8MB, wall time: 146.3s
# Delta E = -1.1231e-09, Delta S = 4.6518e-06 (per sweep)
# max trunc_err = 1.0232e-17, max E_trunc = 1.2790e-13
# chi: 200
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-36.5605734408402228, max S=0.2825476260555518, age=40, norm_err=3.3e-13
# Current memory usage 787.8MB, wall time: 42.0s
# Delta E = 3.1974e-13, Delta S = 1.0803e-10 (per sweep)
# max trunc_err = 2.5641e-17, max E_trunc = 2.7711e-13
# chi: 200
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 5 sweeps, max chi=200
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))
#
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(0.8)
# INFO    : myModel: reading 'kr'=np.float64(0.8)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-35.6365426734612853, max S=0.1805555786761976, age=40, norm_err=1.8e-01
# Current memory usage 787.8MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.0234e-01 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 4.9738e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-35.6503705492419627, max S=0.2422823260925689, age=40, norm_err=2.7e-03
# Current memory usage 787.8MB, wall time: 1.1s
# Delta E = -1.3828e-02, Delta S = 9.5567e-02 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 9.2371e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-35.6503852452113676, max S=0.2423685964534829, age=40, norm_err=7.2e-07
# Current memory usage 787.8MB, wall time: 6.2s
# Delta E = -1.4696e-05, Delta S = 2.4180e-03 (per sweep)
# max trunc_err = 2.3911e-20, max E_trunc = 1.8474e-13
# chi: 64
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-35.6503852454833350, max S=0.2423686183327989, age=40, norm_err=3.6e-11
# Current memory usage 787.8MB, wall time: 129.7s
# Delta E = -2.7197e-10, Delta S = 1.9627e-06 (per sweep)
# max trunc_err = 1.8920e-18, max E_trunc = 2.2027e-13
# chi: 200
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-35.6503852454833350, max S=0.2423686183330080, age=40, norm_err=1.4e-13
# Current memory usage 787.8MB, wall time: 41.8s
# Delta E = 0.0000e+00, Delta S = 2.7009e-11 (per sweep)
# max trunc_err = 4.4630e-18, max E_trunc = 2.0606e-13
# chi: 200
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 5 sweeps, max chi=200
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))
#
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(0.7000000000000001)
# INFO    : myModel: reading 'kr'=np.float64(0.7000000000000001)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-34.8149455998274249, max S=0.1511781843086620, age=40, norm_err=1.2e-01
# Current memory usage 787.8MB, wall time: 0.4s
# Delta E = nan, Delta S = 9.6367e-02 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 5.6843e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-34.8223702996604274, max S=0.1986134273404279, age=40, norm_err=1.5e-03
# Current memory usage 787.8MB, wall time: 1.3s
# Delta E = -7.4247e-03, Delta S = 7.0731e-02 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 6.3949e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-34.8223752763105878, max S=0.1986484481693981, age=40, norm_err=2.9e-07
# Current memory usage 787.8MB, wall time: 5.4s
# Delta E = -4.9767e-06, Delta S = 1.3891e-03 (per sweep)
# max trunc_err = 3.1782e-20, max E_trunc = 2.4869e-13
# chi: 64
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-34.8223752763655980, max S=0.1986484613434604, age=40, norm_err=1.0e-11
# Current memory usage 787.8MB, wall time: 134.3s
# Delta E = -5.5010e-11, Delta S = 8.3652e-07 (per sweep)
# max trunc_err = 2.6070e-19, max E_trunc = 1.5632e-13
# chi: 200
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=200
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))
#
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(0.6000000000000001)
# INFO    : myModel: reading 'kr'=np.float64(0.6000000000000001)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-34.0943496574661680, max S=0.1212753331743572, age=40, norm_err=7.7e-02
# Current memory usage 787.8MB, wall time: 0.4s
# Delta E = nan, Delta S = 9.0083e-02 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 6.3949e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-34.0982532897263013, max S=0.1573479602929231, age=40, norm_err=7.3e-04
# Current memory usage 787.8MB, wall time: 1.2s
# Delta E = -3.9036e-03, Delta S = 4.6914e-02 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.8160e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-34.0982551358641572, max S=0.1573692828588957, age=40, norm_err=1.2e-07
# Current memory usage 787.8MB, wall time: 4.6s
# Delta E = -1.8461e-06, Delta S = 7.4617e-04 (per sweep)
# max trunc_err = 2.8712e-20, max E_trunc = 2.7711e-13
# chi: 64
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-34.0982551358751635, max S=0.1573692927973222, age=40, norm_err=4.5e-12
# Current memory usage 787.8MB, wall time: 116.7s
# Delta E = -1.1006e-11, Delta S = 3.7594e-07 (per sweep)
# max trunc_err = 1.3130e-19, max E_trunc = 1.4921e-13
# chi: 181
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=181
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))
#
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(0.5000000000000001)
# INFO    : myModel: reading 'kr'=np.float64(0.5000000000000001)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-33.4971146633996852, max S=0.0963813802391200, age=40, norm_err=6.5e-02
# Current memory usage 787.8MB, wall time: 0.4s
# Delta E = nan, Delta S = 8.5835e-02 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-33.4991872448329744, max S=0.1245739192005091, age=40, norm_err=3.4e-04
# Current memory usage 787.8MB, wall time: 1.0s
# Delta E = -2.0726e-03, Delta S = 2.6434e-02 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 9.2371e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-33.4991879153208671, max S=0.1252703870576720, age=40, norm_err=5.7e-08
# Current memory usage 787.8MB, wall time: 4.5s
# Delta E = -6.7049e-07, Delta S = 4.4397e-04 (per sweep)
# max trunc_err = 3.2139e-20, max E_trunc = 2.5580e-13
# chi: 64
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-33.4991879153233327, max S=0.1252707648063034, age=40, norm_err=2.0e-12
# Current memory usage 787.8MB, wall time: 106.1s
# Delta E = -2.4656e-12, Delta S = 1.8993e-07 (per sweep)
# max trunc_err = 1.1220e-19, max E_trunc = 2.1316e-13
# chi: 154
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=154
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))
#
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(0.40000000000000013)
# INFO    : myModel: reading 'kr'=np.float64(0.40000000000000013)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-33.0358242586787867, max S=0.0988169952613815, age=40, norm_err=6.7e-02
# Current memory usage 787.8MB, wall time: 0.4s
# Delta E = nan, Delta S = 8.6637e-02 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 4.9738e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-33.0369723141960421, max S=0.1127163181321540, age=40, norm_err=2.3e-04
# Current memory usage 787.8MB, wall time: 1.3s
# Delta E = -1.1481e-03, Delta S = 1.1678e-02 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 8.5265e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-33.0369725813841200, max S=0.1134274098722944, age=40, norm_err=1.8e-08
# Current memory usage 787.8MB, wall time: 4.5s
# Delta E = -2.6719e-07, Delta S = 3.8724e-04 (per sweep)
# max trunc_err = 2.2618e-20, max E_trunc = 1.7764e-13
# chi: 64
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-33.0369725813846316, max S=0.1134275242467237, age=40, norm_err=9.6e-13
# Current memory usage 787.8MB, wall time: 98.9s
# Delta E = -5.1159e-13, Delta S = 5.6107e-08 (per sweep)
# max trunc_err = 9.5521e-20, max E_trunc = 1.0658e-13
# chi: 129
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=129
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))
#
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(0.30000000000000016)
# INFO    : myModel: reading 'kr'=np.float64(0.30000000000000016)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-32.7059441638604866, max S=0.1154710681002024, age=40, norm_err=6.6e-02
# Current memory usage 787.8MB, wall time: 0.4s
# Delta E = nan, Delta S = 9.5373e-02 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-32.7066257536806404, max S=0.1183301089097302, age=40, norm_err=2.1e-04
# Current memory usage 787.8MB, wall time: 1.2s
# Delta E = -6.8159e-04, Delta S = 2.2835e-03 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 5.6843e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-32.7066258748549927, max S=0.1191647484359576, age=40, norm_err=1.4e-08
# Current memory usage 787.8MB, wall time: 4.7s
# Delta E = -1.2117e-07, Delta S = 4.0599e-04 (per sweep)
# max trunc_err = 2.0120e-20, max E_trunc = 1.7764e-13
# chi: 64
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-32.7066258748551562, max S=0.1191648236848085, age=40, norm_err=7.1e-13
# Current memory usage 787.8MB, wall time: 90.4s
# Delta E = -1.6342e-13, Delta S = 3.5362e-08 (per sweep)
# max trunc_err = 7.7197e-20, max E_trunc = 1.5632e-13
# chi: 108
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=108
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))
#
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(0.20000000000000018)
# INFO    : myModel: reading 'kr'=np.float64(0.20000000000000018)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-32.4899462461186346, max S=0.1415145524058316, age=40, norm_err=5.7e-02
# Current memory usage 787.8MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.1015e-01 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 4.2633e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-32.4903807589608533, max S=0.1377608448780043, age=40, norm_err=2.0e-04
# Current memory usage 787.8MB, wall time: 1.2s
# Delta E = -4.3451e-04, Delta S = -3.3100e-03 (per sweep)
# max trunc_err = 3.0190e-21, max E_trunc = 6.3949e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-32.4903808124818454, max S=0.1386332031611512, age=40, norm_err=3.1e-09
# Current memory usage 787.8MB, wall time: 5.1s
# Delta E = -5.3521e-08, Delta S = 4.0357e-04 (per sweep)
# max trunc_err = 2.7191e-20, max E_trunc = 1.4211e-13
# chi: 64
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-32.4903808124816678, max S=0.1386332184433276, age=40, norm_err=1.8e-13
# Current memory usage 787.8MB, wall time: 61.4s
# Delta E = 1.7764e-13, Delta S = 6.6534e-09 (per sweep)
# max trunc_err = 6.2379e-20, max E_trunc = 1.0658e-13
# chi: 87
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=87
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))
#
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(0.1000000000000002)
# INFO    : myModel: reading 'kr'=np.float64(0.1000000000000002)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-32.3688814502908286, max S=0.1637329576279569, age=40, norm_err=4.3e-02
# Current memory usage 787.8MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.2304e-01 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 2.8422e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-32.3691586803028883, max S=0.1581336290322651, age=40, norm_err=8.7e-05
# Current memory usage 787.8MB, wall time: 1.1s
# Delta E = -2.7723e-04, Delta S = -5.5355e-03 (per sweep)
# max trunc_err = 8.5217e-21, max E_trunc = 9.9476e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-32.3691586872778458, max S=0.1584928665719270, age=40, norm_err=2.1e-10
# Current memory usage 787.8MB, wall time: 4.7s
# Delta E = -6.9750e-09, Delta S = 1.6504e-04 (per sweep)
# max trunc_err = 3.2057e-20, max E_trunc = 1.3500e-13
# chi: 59
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-32.3691586872778885, max S=0.1584928673336506, age=40, norm_err=1.8e-13
# Current memory usage 787.8MB, wall time: 35.9s
# Delta E = -4.2633e-14, Delta S = 3.3277e-10 (per sweep)
# max trunc_err = 4.4260e-20, max E_trunc = 1.5632e-13
# chi: 65
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=65
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))
#
# INFO    : myModel: reading 'bc_MPS'='finite'
# INFO    : myModel: reading 'L'=40
# INFO    : myModel: reading 'Jx'=1
# INFO    : myModel: reading 'hz'=0.5
# INFO    : myModel: reading 'kl'=np.float64(2.220446049250313e-16)
# INFO    : myModel: reading 'kr'=np.float64(2.220446049250313e-16)
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'combine'=True
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=None
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=200
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-32.3301053061044854, max S=0.1729302924680089, age=40, norm_err=3.7e-02
# Current memory usage 787.8MB, wall time: 0.3s
# Delta E = nan, Delta S = 1.2853e-01 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 5.6843e-14
# chi: 4
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-32.3301892283235404, max S=0.1662744764314648, age=40, norm_err=2.8e-05
# Current memory usage 787.8MB, wall time: 0.8s
# Delta E = -8.3922e-05, Delta S = -6.6625e-03 (per sweep)
# max trunc_err = 3.8810e-21, max E_trunc = 4.9738e-14
# chi: 16
# ================================================================================
# INFO    : TwoSiteDMRGEngine: reading 'max_E_err'=1e-10
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-32.3301892310693688, max S=0.1664071487674298, age=40, norm_err=4.3e-10
# Current memory usage 787.8MB, wall time: 1.3s
# Delta E = -2.7458e-09, Delta S = 5.9909e-05 (per sweep)
# max trunc_err = 2.6054e-20, max E_trunc = 6.3949e-14
# chi: 35
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-32.3301892310693333, max S=0.1664071500852137, age=40, norm_err=3.2e-13
# Current memory usage 787.8MB, wall time: 0.9s
# Delta E = 3.5527e-14, Delta S = 6.0765e-10 (per sweep)
# max trunc_err = 2.6360e-20, max E_trunc = 7.1054e-14
# chi: 36
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=36
# WARNING : /home/ioannisangelotassioulas/Documents/master_thesis/.venv/lib64/python3.10/site-packages/tenpy/tools/params.py:243: UserWarning: unused option ['verbose'] for config TwoSiteDMRGEngine
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))

# %%
print(M.all_coupling_terms().to_TermList() + M.all_onsite_terms().to_TermList())
# Out:
# 1.00000 * Sx_0 Sx_1 +
# 1.00000 * Sx_1 Sx_2 +
# 1.00000 * Sx_2 Sx_3 +
# 1.00000 * Sx_3 Sx_4 +
# 1.00000 * Sx_4 Sx_5 +
# 1.00000 * Sx_5 Sx_6 +
# 1.00000 * Sx_6 Sx_7 +
# 1.00000 * Sx_7 Sx_8 +
# 1.00000 * Sx_8 Sx_9 +
# 1.00000 * Sx_9 Sx_10 +
# 1.00000 * Sz_40 +
# 1.00000 * Sz_41 +
# 1.00000 * Sz_42 +
# 1.00000 * Sz_43 +
# 1.00000 * Sz_44 +
# 1.00000 * Sz_45 +
# 1.00000 * Sz_46 +
# 1.00000 * Sz_47 +
# 1.00000 * Sz_48 +
# 1.00000 * Sz_49 +
# 1.00000 * Sz_50 +
# 1.00000 * Sz_51 +
# 1.00000 * Sz_52 +
# 1.00000 * Sz_53 +
# 1.00000 * Sz_54 +
# 1.00000 * Sz_55 +
# 1.00000 * Sz_56 +
# 1.00000 * Sz_57 +
# 1.00000 * Sz_58 +
# 1.00000 * Sz_59 +
# 1.00000 * Sz_60 +
# 1.00000 * Sz_61 +
# 1.00000 * Sz_62 +
# 1.00000 * Sz_63 +
# 1.00000 * Sz_64 +
# 1.00000 * Sz_65 +
# 1.00000 * Sz_66 +
# 1.00000 * Sz_67 +
# 1.00000 * Sz_68 +
# 1.00000 * Sz_69 +
# 1.00000 * Sz_70 +
# 1.00000 * Sz_71 +
# 1.00000 * Sz_72 +
# 1.00000 * Sz_73 +
# 1.00000 * Sz_74 +
# 1.00000 * Sz_75 +
# 1.00000 * Sz_76 +
# 1.00000 * Sz_77 +
# 1.00000 * Sz_78 +
# 1.00000 * Sz_79 +
# 1.00000 * Sz_80 +
# 1.00000 * Sz_81 +
# 1.00000 * Sz_82 +
# 1.00000 * Sz_83 +
# 1.00000 * Sz_84 +
# 1.00000 * Sz_85 +
# 1.00000 * Sz_86 +
# 1.00000 * Sz_87 +
# 1.00000 * Sz_88 +
# 1.00000 * Sz_89 +
# 1.00000 * Sz_90 +
# 1.00000 * Sz_91 +
# 1.00000 * Sz_92 +
# 1.00000 * Sz_93 +
# 1.00000 * Sz_94 +
# 1.00000 * Sz_95 +
# 1.00000 * Sz_96 +
# 1.00000 * Sz_97 +
# 1.00000 * Sz_98 +
# 1.00000 * Sz_99 +
# 1.00000 * Sz_100 +
# 1.00000 * Sz_101 +
# 1.00000 * Sz_102 +
# 1.00000 * Sz_103 +
# 1.00000 * Sz_104 +
# 1.00000 * Sz_105 +
# 1.00000 * Sz_106 +
# 1.00000 * Sz_107 +
# 1.00000 * Sz_108 +
# 1.00000 * Sz_109 +
# 1.00000 * Sz_110 +
# 1.00000 * Sz_111 +
# 1.00000 * Sz_112 +
# 1.00000 * Sz_113 +
# 1.00000 * Sz_114 +
# 1.00000 * Sz_115 +
# 1.00000 * Sz_116 +
# 1.00000 * Sz_117 +
# 1.00000 * Sz_118 +
# -20.00000 * Sx_119 +
# 1.00000 * Sz_119

# %% [markdown]
# ## Energy

# %% [markdown]
# ## Magnetization Profile

# %%
# onsite expectation values
filename = os.path.join(os.getcwd(), "First_Run")
print(filename)

for i in os.listdir(filename):

    fig, ax = plt.subplots(1, 3, figsize=(15, 5))
    loc = os.path.join(filename, i)
    with open(loc, 'rb') as f:
        data = pickle.load(f)
        psi = data['psi']
    
    i = os.path.splitext(i)[0]
    h, k = i.split("_")

    x = np.arange(psi.L)
    X = psi.expectation_value("Sigmax")
    Z = psi.expectation_value("Sigmaz")
    Y = psi.expectation_value("Sigmay")
    
    ax[0].plot(x, X, label=f"{h}, {k}")
    ax[0].legend()
    ax[1].plot(x, Y, label=f"{h}, {k}")
    ax[2].plot(x, Z, label=f"{h}, {k}")
   
    plt.xlabel("site")
    plt.ylabel("onsite expectation value")
    plt.legend()
    plt.show()
# Out:
# /home/ioannisangelotassioulas/Documents/master_thesis/books/First_Run

# %% [markdown]
# ## Correlation Functions

# %%
# correlation functions

print(filename)

for i in os.listdir(filename):

    loc = os.path.join(filename, i)
    with open(loc, 'rb') as f:
        data = pickle.load(f)
        psi = data['psi']
    
    i = os.path.splitext(i)[0]
    h, k = i.split("_")

    i0 = psi.L // 2  # for fixed `i`
    j = np.arange(i0 + 1, psi.L)

    XX = psi.term_correlation_function_right([("Sigmax", 0)], [("Sigmax", 0)], i_L=i0, j_R=j)
    XX_disc = XX - X[i0] * X[j]

    YY = psi.term_correlation_function_right([("Sigmay", 0)], [("Sigmay", 0)], i_L=i0, j_R=j)
    YY_disc = YY - Y[i0] * Y[j]

    ZZ = psi.term_correlation_function_right([("Sigmaz", 0)], [("Sigmaz", 0)], i_L=i0, j_R=j)
    ZZ_disc = ZZ - Z[i0] * Z[j]

    XY = psi.term_correlation_function_right([("Sigmax", 0)], [("Sigmay", 0)], i_L=i0, j_R=j)
    XY_disc = XY - X[i0] * Y[j]

    XZ = psi.term_correlation_function_right([("Sigmax", 0)], [("Sigmaz", 0)], i_L=i0, j_R=j)
    XZ_disc = XZ - X[i0] * Z[j]

    YZ = psi.term_correlation_function_right([("Sigmay", 0)], [("Sigmaz", 0)], i_L=i0, j_R=j)
    YZ_disc = YZ - Y[i0] * Z[j]


    dx = j - i0
    plt.figure()
    plt.plot(dx, np.abs(XX_disc), label="X X")
    plt.plot(dx, np.abs(YY_disc), label="Y Y")
    plt.plot(dx, np.abs(ZZ_disc), label="Z Z")
    plt.plot(dx, np.abs(XY_disc), label="X Y")
    plt.plot(dx, np.abs(XZ_disc), label="X Z")
    plt.plot(dx, np.abs(YZ_disc), label="Y Z")
    plt.xlabel(r"distance $|i-j|$")
    plt.ylabel(r"disconnected correlations $\langle A_i A_j\rangle - \langle A_i \rangle\langle A_j\rangle$")
    plt.title(f"Correlations ({h}, {k})")
    plt.legend()
    plt.semilogy()
    plt.show()
# Out:
# /home/ioannisangelotassioulas/Documents/master_thesis/books/First_Run

# %% [markdown]
# ## Entanglement Entropy

# %%
S = psi.entanglement_entropy()

bonds = np.arange(0.5, psi.L-1)
plt.plot(bonds, S, 'o', label="S")

# preform fit to extract the central charge
central_charge, const, res = tenpy.tools.fit.central_charge_from_S_profile(psi)
fit = tenpy.tools.fit.entropy_profile_from_CFT(bonds + 0.5, psi.L, central_charge, const)
print(f"extraced central charge {central_charge:.5f} with residuum {res:.2e}")
print("(Expect central charge = 0.5 for the transverse field Ising model.)")
plt.plot(bonds, fit, label=f"fit with $c={central_charge:.3f}$")
plt.xlabel("bond")
plt.ylabel("entanglement entropy $S$")
plt.legend()
plt.show()
# Out:
# extraced central charge 0.47896 with residuum 4.26e-09
# (Expect central charge = 0.5 for the transverse field Ising model.)
